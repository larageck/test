# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
h= pd.Series(np.array([1,7,9]))
print(h)
# Out:
# 0    1
# 1    7
# 2    9
# dtype: int64

# %%
##h.index --> Index ändern möglich zu a, b,c zB

# %%
h.index = ['a', 'b', 'c']
print(h)
# Out:
# a    1
# b    7
# c    9
# dtype: int64

# %%
States = pd.read_csv('states_by_country_code.csv')
print(States)
# Out:
#      State Code                   State Name Country Code
# 0           BDS                   Badakhshan           AF
# 1           BDG                      Badghis           AF
# 2           BGL                      Baghlan           AF
# 3           BAL                        Balkh           AF
# 4           BAM                       Bamyan           AF
# ...         ...                          ...          ...
# 4984         MW    Mashonaland West Province           ZW
# 4985         MV            Masvingo Province           ZW
# 4986         MN  Matabeleland North Province           ZW
# 4987         MS  Matabeleland South Province           ZW
# 4988         MI            Midlands Province           ZW
#
# [4989 rows x 3 columns]

# %%
##index ändern in dataframes ##States.set_index('State Code')

# %%
States = States.set_index('State Code')
print(States)
# Out:
#                              State Name Country Code
# State Code
# BDS                          Badakhshan           AF
# BDG                             Badghis           AF
# BGL                             Baghlan           AF
# BAL                               Balkh           AF
# BAM                              Bamyan           AF
# ...                                 ...          ...
# MW            Mashonaland West Province           ZW
# MV                    Masvingo Province           ZW
# MN          Matabeleland North Province           ZW
# MS          Matabeleland South Province           ZW
# MI                    Midlands Province           ZW
#
# [4989 rows x 2 columns]

# %%
##reset index. rückgängig machen, immer drop den letzen nicht vergessen

# %%
h.reset_index(drop=True)
# Out:
# 0    1
# 1    7
# 2    9
# dtype: int64

# %%
# Out:
# <bound method Series.reset_index of a    1
# b    7
# c    9
# dtype: int64>

# %%
##change again to the colomn

# %%
States = States.reset_index()
States
# Out:
#      State Code                   State Name Country Code
# 0           BDS                   Badakhshan           AF
# 1           BDG                      Badghis           AF
# 2           BGL                      Baghlan           AF
# 3           BAL                        Balkh           AF
# 4           BAM                       Bamyan           AF
# ...         ...                          ...          ...
# 4984         MW    Mashonaland West Province           ZW
# 4985         MV            Masvingo Province           ZW
# 4986         MN  Matabeleland North Province           ZW
# 4987         MS  Matabeleland South Province           ZW
# 4988         MI            Midlands Province           ZW
#
# [4989 rows x 3 columns]

# %%
##sorting data mit .sort_values

# %%
States.sort_values('State Name')
# Out:
#      State Code              State Name Country Code
# 4948         AD                   'Adan           YE
# 4949         AM                  'Amran           YE
# 3483         14                   'Asir           SA
# 3850          C                A Coruña           ES
# 3461         AA                   A'ana           WS
# ...         ...                     ...          ...
# 3787        193  Žužemberk Municipality           SI
# 993         635        Žďár nad Sázavou           CZ
# 2685         SD     Șoldănești District           MD
# 2687         SV    Ștefan Vodă District           MD
# 4208          1                    ʻEua           TO
#
# [4989 rows x 3 columns]

# %%
##sorting ascending=False dann sortieren in umgekehrter reihenfolge also absteigend

# %%
States.sort_values('State Name', ascending=False)
# Out:
#      State Code              State Name Country Code
# 4208          1                    ʻEua           TO
# 2687         SV    Ștefan Vodă District           MD
# 2685         SD     Șoldănești District           MD
# 993         635        Žďár nad Sázavou           CZ
# 3787        193  Žužemberk Municipality           SI
# ...         ...                     ...          ...
# 3461         AA                   A'ana           WS
# 3850          C                A Coruña           ES
# 3483         14                   'Asir           SA
# 4949         AM                  'Amran           YE
# 4948         AD                   'Adan           YE
#
# [4989 rows x 3 columns]

# %% [markdown]
# Exercise 1: read in the file country_full.csv, (a) set the index to country-code, (b) reset the index, and (c) sort the table based on column region-code.

# %%
country_full = pd.read_csv('country_full.csv')
print(country_full)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
 country_full = country_full.set_index('country-code')
print(country_full)
# Out:
#                            name alpha-2 alpha-3     iso_3166-2   region  \
# country-code
# 4                   Afghanistan      AF     AFG  ISO 3166-2:AF     Asia
# 248               Åland Islands      AX     ALA  ISO 3166-2:AX   Europe
# 8                       Albania      AL     ALB  ISO 3166-2:AL   Europe
# 12                      Algeria      DZ     DZA  ISO 3166-2:DZ   Africa
# 16               American Samoa      AS     ASM  ISO 3166-2:AS  Oceania
# ...                         ...     ...     ...            ...      ...
# 876           Wallis and Futuna      WF     WLF  ISO 3166-2:WF  Oceania
# 732              Western Sahara      EH     ESH  ISO 3166-2:EH   Africa
# 887                       Yemen      YE     YEM  ISO 3166-2:YE     Asia
# 894                      Zambia      ZM     ZMB  ISO 3166-2:ZM   Africa
# 716                    Zimbabwe      ZW     ZWE  ISO 3166-2:ZW   Africa
#
#                       sub-region intermediate-region  region-code  \
# country-code
# 4                  Southern Asia                 NaN        142.0
# 248              Northern Europe                 NaN        150.0
# 8                Southern Europe                 NaN        150.0
# 12               Northern Africa                 NaN          2.0
# 16                     Polynesia                 NaN          9.0
# ...                          ...                 ...          ...
# 876                    Polynesia                 NaN          9.0
# 732              Northern Africa                 NaN          2.0
# 887                 Western Asia                 NaN        142.0
# 894           Sub-Saharan Africa      Eastern Africa          2.0
# 716           Sub-Saharan Africa      Eastern Africa          2.0
#
#               sub-region-code  intermediate-region-code
# country-code
# 4                        34.0                       NaN
# 248                     154.0                       NaN
# 8                        39.0                       NaN
# 12                       15.0                       NaN
# 16                       61.0                       NaN
# ...                       ...                       ...
# 876                      61.0                       NaN
# 732                      15.0                       NaN
# 887                     145.0                       NaN
# 894                     202.0                      14.0
# 716                     202.0                      14.0
#
# [249 rows x 10 columns]

# %%
country_full = country_full.reset_index()
country_full
# Out:
#      country-code               name alpha-2 alpha-3     iso_3166-2   region  \
# 0               4        Afghanistan      AF     AFG  ISO 3166-2:AF     Asia
# 1             248      Åland Islands      AX     ALA  ISO 3166-2:AX   Europe
# 2               8            Albania      AL     ALB  ISO 3166-2:AL   Europe
# 3              12            Algeria      DZ     DZA  ISO 3166-2:DZ   Africa
# 4              16     American Samoa      AS     ASM  ISO 3166-2:AS  Oceania
# ..            ...                ...     ...     ...            ...      ...
# 244           876  Wallis and Futuna      WF     WLF  ISO 3166-2:WF  Oceania
# 245           732     Western Sahara      EH     ESH  ISO 3166-2:EH   Africa
# 246           887              Yemen      YE     YEM  ISO 3166-2:YE     Asia
# 247           894             Zambia      ZM     ZMB  ISO 3166-2:ZM   Africa
# 248           716           Zimbabwe      ZW     ZWE  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
##achtung macht neuen ausschnitt, kein print möglich, geht nur wenn ein neues erstellt wird

# %%
country_full.sort_values('region-code')
# Out:
#      country-code           name alpha-2 alpha-3     iso_3166-2  region  \
# 248           716       Zimbabwe      ZW     ZWE  ISO 3166-2:ZW  Africa
# 206           710   South Africa      ZA     ZAF  ISO 3166-2:ZA  Africa
# 208           728    South Sudan      SS     SSD  ISO 3166-2:SS  Africa
# 211           729          Sudan      SD     SDN  ISO 3166-2:SD  Africa
# 94            624  Guinea-Bissau      GW     GNB  ISO 3166-2:GW  Africa
# ..            ...            ...     ...     ...            ...     ...
# 215           756    Switzerland      CH     CHE  ISO 3166-2:CH  Europe
# 92            831       Guernsey      GG     GGY  ISO 3166-2:GG  Europe
# 85            292      Gibraltar      GI     GIB  ISO 3166-2:GI  Europe
# 157           528    Netherlands      NL     NLD  ISO 3166-2:NL  Europe
# 8              10     Antarctica      AQ     ATA  ISO 3166-2:AQ     NaN
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 206  Sub-Saharan Africa     Southern Africa          2.0            202.0
# 208  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 211     Northern Africa                 NaN          2.0             15.0
# 94   Sub-Saharan Africa      Western Africa          2.0            202.0
# ..                  ...                 ...          ...              ...
# 215      Western Europe                 NaN        150.0            155.0
# 92      Northern Europe     Channel Islands        150.0            154.0
# 85      Southern Europe                 NaN        150.0             39.0
# 157      Western Europe                 NaN        150.0            155.0
# 8                   NaN                 NaN          NaN              NaN
#
#      intermediate-region-code
# 248                      14.0
# 206                      18.0
# 208                      14.0
# 211                       NaN
# 94                       11.0
# ..                        ...
# 215                       NaN
# 92                      830.0
# 85                        NaN
# 157                       NaN
# 8                         NaN
#
# [249 rows x 11 columns]

# %%
country_full.sort_values('region-code', ascending=False)
# Out:
#      country-code                    name alpha-2 alpha-3     iso_3166-2  \
# 85            292               Gibraltar      GI     GIB  ISO 3166-2:GI
# 129           440               Lithuania      LT     LTU  ISO 3166-2:LT
# 75            246                 Finland      FI     FIN  ISO 3166-2:FI
# 146           498   Moldova (Republic of)      MD     MDA  ISO 3166-2:MD
# 213           744  Svalbard and Jan Mayen      SJ     SJM  ISO 3166-2:SJ
# ..            ...                     ...     ...     ...            ...
# 116           404                   Kenya      KE     KEN  ISO 3166-2:KE
# 94            624           Guinea-Bissau      GW     GNB  ISO 3166-2:GW
# 93            324                  Guinea      GN     GIN  ISO 3166-2:GN
# 248           716                Zimbabwe      ZW     ZWE  ISO 3166-2:ZW
# 8              10              Antarctica      AQ     ATA  ISO 3166-2:AQ
#
#      region          sub-region intermediate-region  region-code  \
# 85   Europe     Southern Europe                 NaN        150.0
# 129  Europe     Northern Europe                 NaN        150.0
# 75   Europe     Northern Europe                 NaN        150.0
# 146  Europe      Eastern Europe                 NaN        150.0
# 213  Europe     Northern Europe                 NaN        150.0
# ..      ...                 ...                 ...          ...
# 116  Africa  Sub-Saharan Africa      Eastern Africa          2.0
# 94   Africa  Sub-Saharan Africa      Western Africa          2.0
# 93   Africa  Sub-Saharan Africa      Western Africa          2.0
# 248  Africa  Sub-Saharan Africa      Eastern Africa          2.0
# 8       NaN                 NaN                 NaN          NaN
#
#      sub-region-code  intermediate-region-code
# 85              39.0                       NaN
# 129            154.0                       NaN
# 75             154.0                       NaN
# 146            151.0                       NaN
# 213            154.0                       NaN
# ..               ...                       ...
# 116            202.0                      14.0
# 94             202.0                      11.0
# 93             202.0                      11.0
# 248            202.0                      14.0
# 8                NaN                       NaN
#
# [249 rows x 11 columns]

# %%
###plotting

# %%
##package nicht notwendig .plt

# %%
country = pd.read_csv('country_full.csv')
print(country)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
##makes a list of colomns --> short cut Doppelklammer und namen für die die man will, alternative country.loc und country.iloc 
nach oben der index im diagramm, werte unten x-achse

# %%
##nur für spalten mit der Methode

# %%
country[['country-code', 'region-code']].hist();

# %% [markdown]
# Try it on 2nd row and all the columns

# %%
##Zeile extra Klammer, Zeile, dann Spalte, iloc immer excluded --> beides möglich, bei zeile 0  geht es los

# %%
country.iloc[[1],:].hist();

# %%
country.loc[[1],:].hist();

# %%
##line plot mit achse index x achse

# %%
country['country-code'].plot();

# %%
country.set_index('name')['country-code'].plot(linewidth=2.5, color='green');

# %%
##scatter plot immer erst x und dann y achse

# %%
country.plot.scatter(x='country-code', y='region-code');

# %% [markdown]
# Exercise 2: Read the climate.csv file to a variable named 'climate', generate a line plot from 'Temperature (Celsius)', in the next step change the index to Country and in the 3rd step create a plot with all 3 variables and set the index to the Date. (put the title and axes labels)

# %%
climate = pd.read_csv('climate.csv')
print(climate)
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)
# 0                  10
# 1                  12
# 2                   8
# 3                  15
# 4                  13
# 5                  10
# 6                   8
# 7                   9
# 8                   7
# 9                  11
# 10                 10
# 11                 12

# %%
climate['Temperature (Celsius)'].plot();
plt.legend();

# %%
climate.set_index('Country')
# Out:
#                       Date  Temperature (Celsius)  Humidity (%)  \
# Country
# United States   2023-05-01                   22.5            60
# United States   2023-05-02                   20.7            55
# United States   2023-05-03                   25.2            68
# Canada          2023-05-01                   18.9            50
# Canada          2023-05-02                   17.4            48
# Canada          2023-05-03                   20.1            52
# United Kingdom  2023-05-01                   15.2            70
# United Kingdom  2023-05-02                   14.8            72
# United Kingdom  2023-05-03                   16.5            68
# Germany         2023-05-01                   20.7            60
# Germany         2023-05-02                   22.1            62
# Germany         2023-05-03                   19.8            58
#
#                 Wind Speed (km/h)
# Country
# United States                  10
# United States                  12
# United States                   8
# Canada                         15
# Canada                         13
# Canada                         10
# United Kingdom                  8
# United Kingdom                  9
# United Kingdom                  7
# Germany                        11
# Germany                        10
# Germany                        12

# %%
##ha = alignments
##plt.legend(); nicht unbedingt notwendig
#plt.xticks(rotation=45, ha='right');
#plt.legend();

# %%
climate.set_index('Date')[:].plot(linewidth=2.5, color='green');
plt.xticks(rotation=45, ha='right');
plt.legend();

# %%
climate.set_index('Date')[:].plot(linewidth=2.5, color=('green','yellow', 'red'));

# %%
climate.set_index('Date')[:].plot();

# %%
#climate.set_index('Country')
#countries = climatte.index.tolist()
#positions = range(len(countries))
#plt.xticks(positions, countries, rotation=45, ha='right')
#plt.show()
##plt.tick_params(axis='both', labelsize=20);   --> achsenbeschriftung
##hier alles in einem Diagramm beachtet

# %%
climate.set_index('Date')[['Temperature (Celsius)', 'Humidity (%)', 'Wind Speed (km/h)']].plot(linewidth=1.5, color=('green','yellow', 'red'));
plt.xticks(rotation=45, ha='right');
plt.xlabel('Date', fontsize=16);
plt.ylabel('values', fontsize=16);
plt.title('climate', fontsize=16);
plt.tick_params(axis='both', labelsize=16);

# %%
climate.set_index('Date')[:].plot(linewidth=1.5, color=('green','yellow', 'red'));
plt.xticks(rotation=45, ha='right');
plt.xlabel('Date', fontsize=16);
plt.ylabel('values', fontsize=16);
plt.title('climate', fontsize=16);
plt.tick_params(axis='both', labelsize=12);

# %%
###Operators

# %%
climate = pd.read_csv('climate.csv')
print(climate)
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)
# 0                  10
# 1                  12
# 2                   8
# 3                  15
# 4                  13
# 5                  10
# 6                   8
# 7                   9
# 8                   7
# 9                  11
# 10                 10
# 11                 12

# %%
climate['Temperature (Celsius)'].min()
# Out:
# 14.8

# %%
climate['Temperature (Celsius)'].max()
# Out:
# 25.2

# %%
climate['Temperature (Celsius)'].mean()
# Out:
# 19.491666666666667

# %%
##indexing doppelklammer für liste nicht vergessen

# %%
climate[['Temperature (Celsius)','Humidity (%)']].mean()
# Out:
# Temperature (Celsius)    19.491667
# Humidity (%)             60.250000
# dtype: float64

# %%
climate[['Temperature (Celsius)','Humidity (%)']]-10
# Out:
#     Temperature (Celsius)  Humidity (%)
# 0                    12.5            50
# 1                    10.7            45
# 2                    15.2            58
# 3                     8.9            40
# 4                     7.4            38
# 5                    10.1            42
# 6                     5.2            60
# 7                     4.8            62
# 8                     6.5            58
# 9                    10.7            50
# 10                   12.1            52
# 11                    9.8            48

# %%
##neue spalte erstellen und zu tabelle hinzufügen, in die ergebnis der rechung rein kommt

# %%
climate['df'] = climate['Temperature (Celsius)'] - climate['Humidity (%)']
print(climate)
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)    df
# 0                  10 -37.5
# 1                  12 -34.3
# 2                   8 -42.8
# 3                  15 -31.1
# 4                  13 -30.6
# 5                  10 -31.9
# 6                   8 -54.8
# 7                   9 -57.2
# 8                   7 -51.5
# 9                  11 -39.3
# 10                 10 -39.9
# 11                 12 -38.2

# %%
##spalte dann immer y-achse hier df

# %%
climate.set_index('Date')['df'].plot();
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# Exercise 3: create a column as the sum of the wind speed and humidity and create a scatter plot between the new column and the temperature

# %%
climate['sum_w_h'] = climate['Wind Speed (km/h)'] + climate['Humidity (%)']
print(climate)
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)    df  rain  sum_w_h
# 0                  10 -37.5    10       70
# 1                  12 -34.3    10       67
# 2                   8 -42.8    10       76
# 3                  15 -31.1    10       65
# 4                  13 -30.6    10       61
# 5                  10 -31.9    10       62
# 6                   8 -54.8    10       78
# 7                   9 -57.2    10       81
# 8                   7 -51.5    10       75
# 9                  11 -39.3    10       71
# 10                 10 -39.9    10       72
# 11                 12 -38.2    10       70

# %%
climate.plot.scatter(x='sum_w_h', y='Temperature (Celsius)');

# %% [markdown]
# ##Excercise 4 Add a colomn named 'rain' with a duplicated value over all rows

# %%
climate['rain'] = 10
print(climate)
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)    df  sum_w_h  rain
# 0                  10 -37.5       70    10
# 1                  12 -34.3       67    10
# 2                   8 -42.8       76    10
# 3                  15 -31.1       65    10
# 4                  13 -30.6       61    10
# 5                  10 -31.9       62    10
# 6                   8 -54.8       78    10
# 7                   9 -57.2       81    10
# 8                   7 -51.5       75    10
# 9                  11 -39.3       71    10
# 10                 10 -39.9       72    10
# 11                 12 -38.2       70    10

# %%
##axis = row --> über alle Zeilen
##climate.drop heißt löschen

# %%
climate = climate.drop(['sum_w_h'], axis=1)
climate
# Out:
#            Country        Date  Temperature (Celsius)  Humidity (%)  \
# 0    United States  2023-05-01                   22.5            60
# 1    United States  2023-05-02                   20.7            55
# 2    United States  2023-05-03                   25.2            68
# 3           Canada  2023-05-01                   18.9            50
# 4           Canada  2023-05-02                   17.4            48
# 5           Canada  2023-05-03                   20.1            52
# 6   United Kingdom  2023-05-01                   15.2            70
# 7   United Kingdom  2023-05-02                   14.8            72
# 8   United Kingdom  2023-05-03                   16.5            68
# 9          Germany  2023-05-01                   20.7            60
# 10         Germany  2023-05-02                   22.1            62
# 11         Germany  2023-05-03                   19.8            58
#
#     Wind Speed (km/h)    df  rain
# 0                  10 -37.5    10
# 1                  12 -34.3    10
# 2                   8 -42.8    10
# 3                  15 -31.1    10
# 4                  13 -30.6    10
# 5                  10 -31.9    10
# 6                   8 -54.8    10
# 7                   9 -57.2    10
# 8                   7 -51.5    10
# 9                  11 -39.3    10
# 10                 10 -39.9    10
# 11                 12 -38.2    10

# %%
climate[climate['Temperature (Celsius)'] > 22]

# %%
new_filter = (climate['Temperature (Celsius)'] == 18.9) | (climate['Temperature (Celsius)'] == 20.1)
climate[new_filter]

# %%
new_filter = climate['Temperature (Celsius)'].isin([18.9,20.1])
climate[new_filter]

# %%
climate.loc[climate['Temperature (Celsius)'] > 18.9, 'Temperature (Celsius)'] = 20
climate

# %% [markdown]
# Exercise 5: substitute the humidity values above 60 with 65 in the 'Humidity (%)' column of the 'climate' DataFrame

# %%
currency = pd.read_csv('currency.csv')
print(currency)

# %%
currency2 = currency

# %%
currency2.iloc[1, 1] = 50
currency2

# %%
currency

# %%
currency = pd.read_csv('currency.csv')
print(currency)

# %%
currency2 = currency.copy()

# %%
currency2.iloc[1, 1] = 50
currency2

# %%
currency

# %% [markdown]
# Exercise 6: read in the climate.csv file again, make a copy of the table, substitude the wind speeds equall to 13 and 8 with 10 (with both conditional and isin methods) and creat a plot of wind speed with respect to the countries name, include title, labels and legend in your figure

# %%
currency2.to_csv('currency2.csv', index=False)

# %% [markdown]
# Exercise 7: Make a copy of the currency file in which the value in the 2nd row and 3rd column has been substituted, and save this new file.

# %% [markdown]
# Reference: https://jupyter.org https://the-turing-way.netlify.app/communication/binder/zero-to-binder.html https://docs.python.org https://wsform.com/knowledgebase/sample-csv-files/ https://geobgu.xyz/py/
